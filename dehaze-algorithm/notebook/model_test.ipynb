# %%
from copy import deepcopy
import torch
import platform
platform = platform.system()
if platform == 'Linux':
    # !BASICSR_JIT=True
else:
    # !set BASICSR_JIT=True

from basicsr import get_root_logger


def print_different_keys_loading(crt_net, load_net, strict=True):
    """Print keys with different name or different size when loading models.

    1. Print keys with different names.
    2. If strict=False, print the same key but with different tensor size.
        It also ignore these keys with different sizes (not load).

    Args:
        crt_net (torch model): Current network.
        load_net (dict): Loaded network.
        strict (bool): Whether strictly loaded. Default: True.
    """
    crt_net = crt_net.state_dict()
    crt_net_keys = set(crt_net.keys())
    load_net_keys = set(load_net.keys())

    logger = get_root_logger()
    if crt_net_keys != load_net_keys:
        logger.warning('当前神经网络 相比 已加载的神经网络 多出的网络层:')
        for v in sorted(list(crt_net_keys - load_net_keys)):
            logger.warning(f'  {v}')
        logger.warning('已加载的神经网络 相比 当前神经网络 多出的网络参数层:')
        for v in sorted(list(load_net_keys - crt_net_keys)):
            logger.warning(f'  {v}')

    # check the size for the same keys
    if not strict:
        common_keys = crt_net_keys & load_net_keys
        for k in common_keys:
            if crt_net[k].size() != load_net[k].size():
                logger.warning(f'网络参数层[{k}]形状不同，以忽略: 当前网络参数层形状: '
                               f'{crt_net[k].shape}; 已加载网络参数层形状: {load_net[k].shape}')
                load_net[k + '.ignore'] = load_net.pop(k)

def load_network(net, load_path, strict=True, param_key='params'):
    """Load network.

    Args:
        load_path (str): The path of networks to be loaded.
        net (nn.Module): Network.
        strict (bool): Whether strictly loaded.
        param_key (str): The parameter key of loaded network. If set to
            None, use the root 'path'.
            Default: 'params'.
    """
    logger = get_root_logger()
    load_net = torch.load(load_path, map_location=lambda storage, loc: storage)
    if param_key is not None:
        if param_key not in load_net and 'params' in load_net:
            param_key = 'params'
            logger.info('加载中: params_ema（指数滑动平均）不存在，将使用 params')
        load_net = load_net[param_key]
    logger.info(f'从 {load_path} 加载模型 {net.__class__.__name__} 网络参数层为: [{param_key}].')
    # remove unnecessary 'module.'
    for k, v in deepcopy(load_net).items():
        if k.startswith('module.'):
            load_net[k[7:]] = v
            load_net.pop(k)
    print_different_keys_loading(net, load_net, strict)
    net.load_state_dict(load_net, strict=strict)

# %%
from collections import OrderedDict
from basicsr.utils.registry import ARCH_REGISTRY
from basicsr.utils.options import ordered_yaml
import yaml
from basicsr import build_network
from basicsr.archs.ridcp_new_arch import RIDCPNew

pretrained_new_hqp_path = "../pretrained_models/pretrained_HQPs_renamed.pth"
pretrained_new_net_path = "../pretrained_models/pretrained_RIDCP_renamed.pth"
param_key = 'params'

with open("../options/RIDCPNew-pei-NH-HAZE.yml", mode='r') as f:
    opt = yaml.load(f, Loader=ordered_yaml()[0])
hq_opt = opt['network_g'].copy()
hq_opt['LQ_stage'] = False
hq_opt_type = hq_opt["type"]
hq_opt.pop('type')
print(hq_opt)
# print(opt["network_g"])
# net = build_network(hq_opt)
# hqp = build_network(opt['network_g'])

# def func(*, LQ_stage, **kwargs):
#     print(LQ_stage, kwargs)
# func(**hq_opt)
# opt_hqp = {
#     "LQ_stage": False,
#     "frozen_module_keywords": ['quantizer', 'decoder_group', 'after_quant', 'out_conv']
# }
opt_net = {
    #"LQ_stage": True,
    "frozen_module_keywords": ['quantizer', 'decoder_group', 'after_quant', 'out_conv']
}
opts = OrderedDict()
opts["LQ_stage"] = True
opts["frozen_module_keywords"] = ['quantizer', 'decoder_group', 'after_quant', 'out_conv']
print(opts)
net = ARCH_REGISTRY.get(hq_opt_type)(**opt["network_g"])
for key, param in net.state_dict().items():
    print(key)
    

# hqp = ARCH_REGISTRY.get("RIDCPNew")(**opt_hqp)
load_network(net, pretrained_new_net_path, True, param_key)
# load_network(hqp, pretrained_new_hqp_path, True, param_key)
# Out:
# OrderedDict([('LQ_stage', False), ('frozen_module_keywords', ['quantizer', 'decoder_group', 'after_quant', 'out_conv'])])
# OrderedDict([('LQ_stage', True), ('frozen_module_keywords', ['quantizer', 'decoder_group', 'after_quant', 'out_conv'])])
# vq_encoder.in_conv.weight
# vq_encoder.in_conv.bias
# vq_encoder.blocks.0.0.weight
# vq_encoder.blocks.0.0.bias
# vq_encoder.blocks.0.1.conv.0.norm.weight
# vq_encoder.blocks.0.1.conv.0.norm.bias
# vq_encoder.blocks.0.1.conv.2.weight
# vq_encoder.blocks.0.1.conv.2.bias
# vq_encoder.blocks.0.1.conv.3.norm.weight
# vq_encoder.blocks.0.1.conv.3.norm.bias
# vq_encoder.blocks.0.1.conv.5.weight
# vq_encoder.blocks.0.1.conv.5.bias
# vq_encoder.blocks.0.2.conv.0.norm.weight
# vq_encoder.blocks.0.2.conv.0.norm.bias
# vq_encoder.blocks.0.2.conv.2.weight
# vq_encoder.blocks.0.2.conv.2.bias
# vq_encoder.blocks.0.2.conv.3.norm.weight
# vq_encoder.blocks.0.2.conv.3.norm.bias
# vq_encoder.blocks.0.2.conv.5.weight
# vq_encoder.blocks.0.2.conv.5.bias
# vq_encoder.blocks.1.0.weight
# vq_encoder.blocks.1.0.bias
# vq_encoder.blocks.1.1.conv.0.norm.weight
# vq_encoder.blocks.1.1.conv.0.norm.bias
# vq_encoder.blocks.1.1.conv.2.weight
# vq_encoder.blocks.1.1.conv.2.bias
# vq_encoder.blocks.1.1.conv.3.norm.weight
# vq_encoder.blocks.1.1.conv.3.norm.bias
# vq_encoder.blocks.1.1.conv.5.weight
# vq_encoder.blocks.1.1.conv.5.bias
# vq_encoder.blocks.1.2.conv.0.norm.weight
# vq_encoder.blocks.1.2.conv.0.norm.bias
# vq_encoder.blocks.1.2.conv.2.weight
# vq_encoder.blocks.1.2.conv.2.bias
# vq_encoder.blocks.1.2.conv.3.norm.weight
# vq_encoder.blocks.1.2.conv.3.norm.bias
# vq_encoder.blocks.1.2.conv.5.weight
# vq_encoder.blocks.1.2.conv.5.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.norm1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.norm1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.attn.relative_position_index
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.attn.qkv.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.attn.qkv.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.attn.proj.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.attn.proj.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.norm2.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.norm2.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.mlp.fc1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.mlp.fc1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.mlp.fc2.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.0.mlp.fc2.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn_mask
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.norm1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.norm1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn.relative_position_index
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn.qkv.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn.qkv.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn.proj.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.attn.proj.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.norm2.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.norm2.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.mlp.fc1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.mlp.fc1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.mlp.fc2.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.1.mlp.fc2.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.norm1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.norm1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.attn.relative_position_index
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.attn.qkv.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.attn.qkv.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.attn.proj.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.attn.proj.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.norm2.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.norm2.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.mlp.fc1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.mlp.fc1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.mlp.fc2.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.2.mlp.fc2.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.attn_mask
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.norm1.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.norm1.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.attn.relative_position_index
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.attn.qkv.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.attn.qkv.bias
# ridcp_encoder.swin_blks.0.residual_group.blocks.3.attn.proj.weight
# ridcp_encoder.swin_blks.0.residual_group.blocks.3
weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.attn.proj.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.norm2.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.norm2.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.mlp.fc1.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.mlp.fc1.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.mlp.fc2.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.4.mlp.fc2.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn_mask
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.norm1.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.norm1.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn.relative_position_index
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn.qkv.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn.qkv.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn.proj.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.attn.proj.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.norm2.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.norm2.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.mlp.fc1.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.mlp.fc1.bias
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.mlp.fc2.weight
# ridcp_encoder.swin_blks.2.residual_group.blocks.5.mlp.fc2.bias
# ridcp_encoder.swin_blks.2.conv.weight
# ridcp_encoder.swin_blks.2.conv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.norm1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.norm1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.attn.relative_position_index
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.attn.qkv.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.attn.qkv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.attn.proj.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.attn.proj.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.norm2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.norm2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.mlp.fc1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.mlp.fc1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.mlp.fc2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.0.mlp.fc2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn_mask
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.norm1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.norm1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn.relative_position_index
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn.qkv.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn.qkv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn.proj.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.attn.proj.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.norm2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.norm2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.mlp.fc1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.mlp.fc1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.mlp.fc2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.1.mlp.fc2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.norm1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.norm1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.attn.relative_position_index
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.attn.qkv.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.attn.qkv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.attn.proj.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.attn.proj.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.norm2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.norm2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.mlp.fc1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.mlp.fc1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.mlp.fc2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.2.mlp.fc2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn_mask
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.norm1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.norm1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn.relative_position_index
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn.qkv.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn.qkv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn.proj.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.attn.proj.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.norm2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.norm2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.mlp.fc1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.mlp.fc1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.mlp.fc2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.3.mlp.fc2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.norm1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.norm1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.attn.relative_position_index
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.attn.qkv.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.attn.qkv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.attn.proj.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.attn.proj.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.norm2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.norm2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.mlp.fc1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.mlp.fc1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.mlp.fc2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.4.mlp.fc2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn_mask
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.norm1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.norm1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn.relative_position_bias_table
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn.relative_position_index
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn.qkv.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn.qkv.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn.proj.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.attn.proj.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.norm2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.norm2.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.mlp.fc1.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.mlp.fc1.bias
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.mlp.fc2.weight
# ridcp_encoder.swin_blks.3.residual_group.blocks.5.mlp.fc2.bias
# ridcp_encoder.swin_blks.3.conv.weight
# ridcp_encoder.swin_blks.3.conv.bias
# ridcp_decoder.upsampler.0.1.weight
# ridcp_decoder.upsampler.0.1.bias
# ridcp_decoder.upsampler.0.2.conv.0.norm.weight
# ridcp_decoder.upsampler.0.2.conv.0.norm.bias
# ridcp_decoder.upsampler.0.2.conv.2.weight
# ridcp_decoder.upsampler.0.2.conv.2.bias
# ridcp_decoder.upsampler.0.2.conv.3.norm.weight
# ridcp_decoder.upsampler.0.2.conv.3.norm.bias
# ridcp_decoder.upsampler.0.2.conv.5.weight
# ridcp_decoder.upsampler.0.2.conv.5.bias
# ridcp_decoder.upsampler.0.3.conv.0.norm.weight
# ridcp_decoder.upsampler.0.3.conv.0.norm.bias
# ridcp_decoder.upsampler.0.3.conv.2.weight
# ridcp_decoder.upsampler.0.3.conv.2.bias
# ridcp_decoder.upsampler.0.3.conv.3.norm.weight
# ridcp_decoder.upsampler.0.3.conv.3.norm.bias
# ridcp_decoder.upsampler.0.3.conv.5.weight
# ridcp_decoder.upsampler.0.3.conv.5.bias
# ridcp_decoder.upsampler.1.1.weight
# ridcp_decoder.upsampler.1.1.bias
# ridcp_decoder.upsampler.1.2.conv.0.norm.weight
# ridcp_decoder.upsampler.1.2.conv.0.norm.bias
# ridcp_decoder.upsampler.1.2.conv.2.weight
# ridcp_decoder.upsampler.1.2.conv.2.bias
# ridcp_decoder.upsampler.1.2.conv.3.norm.weight
# ridcp_decoder.upsampler.1.2.conv.3.norm.bias
# ridcp_decoder.upsampler.1.2.conv.5.weight
# ridcp_decoder.upsampler.1.2.conv.5.bias
# ridcp_decoder.upsampler.1.3.conv.0.norm.weight
# ridcp_decoder.upsampler.1.3.conv.0.norm.bias
# ridcp_decoder.upsampler.1.3.conv.2.weight
# ridcp_decoder.upsampler.1.3.conv.2.bias
# ridcp_decoder.upsampler.1.3.conv.3.norm.weight
# ridcp_decoder.upsampler.1.3.conv.3.norm.bias
# ridcp_decoder.upsampler.1.3.conv.5.weight
# ridcp_decoder.upsampler.1.3.conv.5.bias
# ridcp_decoder.warp.0.offset.weight
# ridcp_decoder.warp.0.offset.bias
# ridcp_decoder.warp.0.dcn.weight
# ridcp_decoder.warp.0.dcn.bias
# ridcp_decoder.warp.0.dcn.conv_offset.weight
# ridcp_decoder.warp.0.dcn.conv_offset.bias
# ridcp_decoder.warp.1.offset.weight
# ridcp_decoder.warp.1.offset.bias
# ridcp_decoder.warp.1.dcn.weight
# ridcp_decoder.warp.1.dcn.bias
# ridcp_decoder.warp.1.dcn.conv_offset.weight
# ridcp_decoder.warp.1.dcn.conv_offset.bias
# vq_decoder_group.0.block.1.weight
# vq_decoder_group.0.block.1.bias
# vq_decoder_group.0.block.2.conv.0.norm.weight
# vq_decoder_group.0.block.2.conv.0.norm.bias
# vq_decoder_group.0.block.2.conv.2.weight
# vq_decoder_group.0.block.2.conv.2.bias
# vq_decoder_group.0.block.2.conv.3.norm.weight
# vq_decoder_group.0.block.2.conv.3.norm.bias
# vq_decoder_group.0.block.2.conv.5.weight
# vq_decoder_group.0.block.2.conv.5.bias
# vq_decoder_group.0.block.3.conv.0.norm.weight
# vq_decoder_group.0.block.3.conv.0.norm.bias
# vq_decoder_group.0.block.3.conv.2.weight
# vq_decoder_group.0.block.3.conv.2.bias
# vq_decoder_group.0.block.3.conv.3.norm.weight
# vq_decoder_group.0.block.3.conv.3.norm.bias
# vq_decoder_group.0.block.3.conv.5.weight
# vq_decoder_group.0.block.3.conv.5.bias
# vq_decoder_group.1.block.1.weight
# vq_decoder_group.1.block.1.bias
# vq_decoder_group.1.block.2.conv.0.norm.weight
# vq_decoder_group.1.block.2.conv.0.norm.bias
# vq_decoder_group.1.block.2.conv.2.weight
# vq_decoder_group.1.block.2.conv.2.bias
# vq_decoder_group.1.block.2.conv.3.norm.weight
# vq_decoder_group.1.block.2.conv.3.norm.bias
# vq_decoder_group.1.block.2.conv.5.weight
# vq_decoder_group.1.block.2.conv.5.bias
# vq_decoder_group.1.block.3.conv.0.norm.weight
# vq_decoder_group.1.block.3.conv.0.norm.bias
# vq_decoder_group.1.block.3.conv.2.weight
# vq_decoder_group.1.block.3.conv.2.bias
# vq_decoder_group.1.block.3.conv.3.norm.weight
# vq_decoder_group.1.block.3.conv.3.norm.bias
# vq_decoder_group.1.block.3.conv.5.weight
# vq_decoder_group.1.block.3.conv.5.bias
# out_conv.weight
# out_conv.bias
# residual_conv.weight
# residual_conv.bias
# quantizer.embedding.weight
# before_quant.weight
# before_quant.bias
# after_quant.conv.weight
# after_quant.conv.bias
